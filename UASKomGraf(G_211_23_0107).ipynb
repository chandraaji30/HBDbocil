# %% [markdown]
# <a href="https://colab.research.google.com/github/chandraaji30/HBDbocil/blob/main/UASKomGraf(G_211_23_0107).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
# %matplotlib inline
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f74fa0a4-e702-463a-90d9-999513b74699" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f74fa0a4-e702-463a-90d9-999513b74699">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("stock.csv")
df
# Out:
#                                                                            Stock Name;Symbol;Shares;Purchase Price;Cost Basis;Current Price;Market Value;Gain/Loss;Dividend/share;Annual Yield
# Apple;AAPL;100;$90.00;$9                     000.00;$144.13;$14 413.27;$14                                 269.14;$2.28;1.58%
# Microsoft;MSFT;200;$32.00;$6                 400.00;$65.57;$13  114.14;$13                                 048.57;$2.24;2.38%
# Salesforce;CRM;50;$40.00;$2                  000.00;$47.48;$2   374.00;$2                                  352.00;$0.54;1.14%
# Oracle;ORCL;200;$35.00;$7                    000.00;$44.56;$8   912.00;$8                                  822.00;$0.36;0.81%
# Hewlett Packard Enterprise;HPE;500;$18.00;$9 000.00;$14.92;$7   460.00;$7                                  521.00;$0.30;2.01%
# Alphabet;GOOG;100;$225.00;$22                500.00;$223.33;$22 333.00;$22                                 376.00;$0.00;0.00%
# ...

# %%
# Mendapatkan nama kolom atribut
kolom_atribut = ["Purchase Price", "Current Price", "Gain/Loss"]

# Melakukan loop untuk setiap kolom atribut
for kolom in kolom_atribut:
  # Mengambil data kolom atribut
  data_kolom = data[kolom]

  # Menampilkan statistik deskriptif data kolom
  print(f"Statistik Deskriptif {kolom}:")
  print(data_kolom.describe())

  # Membuat histogram untuk data kolom
  plt.figure(figsize=(10, 6))
  data_kolom.hist(bins=20, edgecolor="black")
  plt.xlabel(kolom)
  plt.ylabel("Frekuensi")
  plt.title(f"Distribusi Data {kolom}")
  plt.show()
# Out:
# Statistik Deskriptif Purchase Price:
# count          5
# unique         5
# top       $65.00
# freq           1
# Name: Purchase Price, dtype: object
# Statistik Deskriptif Current Price:
# count          5
# unique         5
# top       $88.33
# freq           1
# Name: Current Price, dtype: object
# Statistik Deskriptif Gain/Loss:
# count              5
# unique             5
# top       $16,495.00
# freq               1
# Name: Gain/Loss, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("stock.csv")
# Assuming 'data' string contains the actual data, let's convert it to a DataFrame
df = pd.DataFrame([x.split(';') for x in data.split('\n')]) # Splitting the string into rows and columns
df.columns = df.iloc[0] # Setting the first row as column headers
df = df[1:] # Removing the header row from the data
data = df.sort_values(by="Dividend/share", ascending=False).head(5) # Now sorting the correctly formatted DataFrame
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Stock Name', y='Dividend/share', data=data, palette='YlGnBu')
plt.xlabel('Stock Names', fontsize=12, weight='bold')
plt.ylabel('Dividend per Share', fontsize=12, weight='bold')
plt.title('Atribut Stock Name dan Symbol yang memiliki Dividen / Share 5 tertinggi', fontsize=14, weight='bold')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-fabf1638861d>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Stock Name', y='Dividend/share', data=data, palette='YlGnBu')

# %%
data_sort = data.sort_values(by="Market Value", ascending=False)
top_5_stocks = data_sort.head(5)
top_5_stocks_df = top_5_stocks[["Stock Name", "Symbol"]]
print(top_5_stocks_df)
# Out:
# 0 Stock Name Symbol
# 8      Cisco   CSCO
# 7      Intel   INTC
# 9   Qualcomm   QCOM
# 1      Apple   AAPL
# 2  Microsoft   MSFT

# %%
import pandas as pd
data_sorted = data.sort_values(by="Annual Yield", ascending=False)
data_7_tertinggi = data_sorted.head(7)
stock_name = data_7_tertinggi["Stock Name"].tolist()
stock_symbol = data_7_tertinggi["Symbol"].tolist()
atribut_baru = pd.DataFrame({"Stock Name": stock_name, "Symbol": stock_symbol})
print(atribut_baru)
# Out:
#   Stock Name Symbol
# 0      Intel   INTC
# 1      Cisco   CSCO
# 2   Qualcomm   QCOM
# 3  Microsoft   MSFT
# 4      Apple   AAPL
